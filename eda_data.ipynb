# %%
#installar librerias
# %pip install pandas numpy matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\pc\desktop\info\fraimel\proyectos ds\proyecto #3 predicción de series de tiempo (forecasting)\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\pc\desktop\info\fraimel\proyectos ds\proyecto #3 predicción de series de tiempo (forecasting)\.venv\lib\site-packages (2.3.5)
# Requirement already satisfied: matplotlib in c:\users\pc\desktop\info\fraimel\proyectos ds\proyecto #3 predicción de series de tiempo (forecasting)\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\pc\desktop\info\fraimel\proyectos ds\proyecto #3 predicción de series de tiempo (forecasting)\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pc\desktop\info\fraimel\proyectos ds\proyecto #3 predicción de series de tiempo (forecasting)\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pc\desktop\info\fraimel\proyectos ds\proyecto #3 predicción de series de tiempo (forecasting)\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pc\desktop\info\fraimel\proyectos ds\proyecto #3 predicción de series de tiempo (forecasting)\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pc\desktop\info\fraimel\proyectos ds\proyecto #3 predicción de series de tiempo (forecasting)\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\pc\desktop\info\fraimel\proyectos ds\proyecto #3 predicción de series de tiempo (forecasting)\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pc\desktop\info\fraimel\proyectos ds\proyecto #3 predicción de series de tiempo (forecasting)\.venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pc\desktop\info\fraimel\proyectos ds\proyecto #3 predicción de series de tiempo (forecasting)\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc\desktop\info\fraimel\proyectos ds\proyecto #3 predicción de series de tiempo (forecasting)\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\pc\desktop\info\fraimel\proyectos ds\proyecto #3 predicción de series de tiempo (forecasting)\.venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\pc\desktop\info\fraimel\proyectos ds\proyecto #3 predicción de series de tiempo (forecasting)\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\pc\desktop\info\fraimel\proyectos ds\proyecto #3 predicción de series de tiempo (forecasting)\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('sales_data_cleaned.csv', encoding='latin1')
df.head(2)
# Out:
#    ordernumber  quantityordered  priceeach  orderlinenumber   sales  \
# 0        10107               30      95.70                2  2871.0
# 1        10121               34      81.35                5  2765.9
#
#     orderdate   status  qtr_id                       month_id  year_id  ...  \
# 0  2003-02-24  shipped       1  1970-01-01 00:00:00.000000002     2003  ...
# 1  2003-05-07  shipped       2  1970-01-01 00:00:00.000000005     2003  ...
#
#   addressline2   city state postalcode country territory contactlastname  \
# 0      level 3    nyc    ny      10022     usa      emea              yu
# 1      level 3  reims    ca      51100  france      emea         henriot
#
#   contactfirstname dealsize    year_id
# 0             kwai    small  2003-01-01
# 1             paul    small  2003-01-01
#
# [2 rows x 26 columns]

# %%
sns.histplot(df['sales'], bins=30)
plt.title('Distribution of Sales')
plt.xlabel('Sales') 
plt.ylabel('Frequency')
plt.show()

# %%
#box plot to identify outliers
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['sales'])
plt.title('Box Plot of Sales')
plt.xlabel('Sales')
plt.show()

# %%
#correlacion
numeric_df = df.select_dtypes(include=[np.number])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix') 
plt.show()

# %%
#relacion entre variables numericas
sns.pairplot(numeric_df)
plt.suptitle('Pairplot of Numerical Features', y=1.02)
plt.show()
